# %%
from sklearn.datasets import make_moons
from matplotlib import pyplot as plt 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
import numpy as np

# %% [markdown]
# <b>Apply K-Means clustering</b>

# %%
np.random.seed(50)
X, y = make_moons(n_samples=500, noise=0.1)

# %%
print('X shape:',X.shape)
# Out:
# X shape: (500, 2)

# %%
plt.scatter(X[:,0], X[:,1] ,c=y )

# %%
k=12 
k=8
k=10

# %%
def get_random(k):
    centroids={}
    while True:
        ri=np.random.choice(range(len(X)), k)
        print(ri)
        if len(ri)==k:
            for i in range(k):
                centroids[i]=X[ri[i]]
            break

    return centroids

# %%
k = 8
c=get_random(k)
print(c)
c=list(c.values())
print(c)
c1=c[0]
c2=c[1]
c3=c[2]
c4=c[3]
c5=c[4]
c6=c[5]
c7=c[6]
c8=c[7]
# Out:
# [ 82 494 185 281 482 176 408 348]
# {0: array([-0.42234474,  0.93317983]), 1: array([1.88697529, 0.19056934]), 2: array([ 1.26351739, -0.47869115]), 3: array([ 1.47511797, -0.48526759]), 4: array([ 0.88071916, -0.69941162]), 5: array([0.83527035, 0.63233558]), 6: array([-0.66708181,  0.74197141]), 7: array([0.80177567, 0.61117936])}
# [array([-0.42234474,  0.93317983]), array([1.88697529, 0.19056934]), array([ 1.26351739, -0.47869115]), array([ 1.47511797, -0.48526759]), array([ 0.88071916, -0.69941162]), array([0.83527035, 0.63233558]), array([-0.66708181,  0.74197141]), array([0.80177567, 0.61117936])]

# %%
def euclidianDistance(arr,c):
    return np.sqrt( ((arr[0]-c[0])*(arr[0]-c[0]))+((arr[1]-c[1])*(arr[1]-c[1])) )

# %%
def grouping(X):
    g1 = []
    g2 = []
    g3 = []
    g4 = []
    g5 = []
    g6 = []
    g7 = []
    g8 = []
   
    
    sz = X.size
    sz/=2
    sz = int (sz)
    #print(sz)
    for i in range(sz):
        data = X[i]
        mn1 = euclidianDistance(data,c1)
        mn2 = euclidianDistance(data,c2)
        mn3 = euclidianDistance(data,c3)
        mn4 = euclidianDistance(data,c4)
        mn5 = euclidianDistance(data,c5)
        mn6 = euclidianDistance(data,c6)
        mn7 = euclidianDistance(data,c7)
        mn8 = euclidianDistance(data,c8)
       
        if mn1<mn2 and mn1<mn3 and mn1<mn4 and mn1<mn5 and mn1<mn6 and mn1<mn7 and mn1<mn8:
            g1.append(data)
        elif mn2<mn1 and mn2<mn3 and mn2<mn4 and mn2<mn5 and mn2<mn6 and mn2<mn7 and mn2<mn8:
            g2.append(data)
        elif mn3<mn1 and mn3<mn2 and mn3<mn4 and mn3<mn5 and mn3<mn6 and mn3<mn7 and mn3<mn8:
            g3.append(data)
        elif mn4<mn1 and mn4<mn2 and mn4<mn3 and mn4<mn5 and mn4<mn6 and mn4<mn7 and mn4<mn8:
            g4.append(data)
        elif mn5<mn1 and mn5<mn2 and mn5<mn3 and mn5<mn4 and mn5<mn6 and mn5<mn7 and mn5<mn8:
            g5.append(data)
        elif mn6<mn1 and mn6<mn2 and mn6<mn3 and mn6<mn4 and mn6<mn5 and mn6<mn7 and mn6<mn8:
            g6.append(data)
        elif mn7<mn1 and mn7<mn2 and mn7<mn3 and mn7<mn4 and mn7<mn6 and mn7<mn5 and mn7<mn8:
            g7.append(data)
        else:
            g8.append(data)
    return g1,g2,g3,g4,g5,g6,g7,g8

# %%
def average(grp):
    GRP = np.array(grp)
    sz = GRP.size
    sz/=2
    sz = int (sz)
    left=0
    right=0
   # print(sz)
    for i in range(sz):
        t = GRP[i]
        left+=t[0]
        right+=t[1]
    c = [left/sz,right/sz]
    return c

# %%
g1,g2,g3,g4,g5,g6,g7,g8= grouping(X)
c1 = average(g1)
c2 = average(g2)
c3 = average(g3)
c4 = average(g4)
c5 = average(g5)
c6 = average(g6)
c7 = average(g7)
c8 = average(g8)


while(1):
    g1,g2,g3,g4,g5,g6,g7,g8 = grouping(X)
    c1 = average(g1)
    c2 = average(g2)
    c3 = average(g3)
    c4 = average(g4)
    c5 = average(g5)
    c6 = average(g6)
    c7 = average(g7)
    c8 = average(g8)
    g1,g2,g3,g4,g5,g6,g7,g8 = grouping(X)
    c11 = average(g1)
    c22= average(g2)
    c33 = average(g3)
    c44 = average(g4)
    c55 = average(g5)
    c66 = average(g6)
    c77 = average(g7)
    c88 = average(g8)
    if c1==c11 and c2==c22 and c3==c33 and c4==c44 and c5==c55 and c6==c66 and c7==c77 and c8==c88:
        break

# %%
plt.scatter(X[:,0],X[:,1],c=y )
colmap = {0: 'r', 1: 'r', 2: 'r', 3:'r',4: 'r', 5: 'b', 6: 'b', 7:'b',8:'b', 9: 'b', 10: 'b', 11:'b',12:'b'}
plt.scatter(c1[0], c1[1], color=colmap[0])
plt.scatter(c2[0], c2[1], color=colmap[1])
plt.scatter(c3[0], c3[1], color=colmap[2])
plt.scatter(c4[0], c4[1], color=colmap[3])
plt.scatter(c5[0], c5[1], color=colmap[4])
plt.scatter(c6[0], c6[1], color=colmap[5])
plt.scatter(c7[0], c7[1], color=colmap[6])
plt.scatter(c8[0], c8[1], color=colmap[7])

plt.show()

# %%
k = 10
c=get_random(k)
print(c)
c=list(c.values())
print(c)
c1=c[0]
c2=c[1]
c3=c[2]
c4=c[3]
c5=c[4]
c6=c[5]
c7=c[6]
c8=c[7]
c9=c[8]
c10=c[9]
# Out:
# [499 455 282 226  62  93 228 352 473 480]
# {0: array([-0.73325796,  0.84605439]), 1: array([ 0.50703715, -0.2579914 ]), 2: array([0.10076424, 1.00826307]), 3: array([-0.13705788,  0.83677684]), 4: array([-0.83388466,  0.11412572]), 5: array([-0.234336  ,  0.84252694]), 6: array([0.77906477, 0.65747048]), 7: array([ 0.21187383, -0.11480557]), 8: array([ 1.34847354, -0.46729188]), 9: array([ 1.9275639 , -0.06897657])}
# [array([-0.73325796,  0.84605439]), array([ 0.50703715, -0.2579914 ]), array([0.10076424, 1.00826307]), array([-0.13705788,  0.83677684]), array([-0.83388466,  0.11412572]), array([-0.234336  ,  0.84252694]), array([0.77906477, 0.65747048]), array([ 0.21187383, -0.11480557]), array([ 1.34847354, -0.46729188]), array([ 1.9275639 , -0.06897657])]

# %%
def grouping(X):
    g1 = []
    g2 = []
    g3 = []
    g4 = []
    g5 = []
    g6 = []
    g7 = []
    g8 = []
    g9 = []
    g10 = []
   
    
    sz = X.size
    sz/=2
    sz = int (sz)
    #print(sz)
    for i in range(sz):
        data = X[i]
        mn1 = euclidianDistance(data,c1)
        mn2 = euclidianDistance(data,c2)
        mn3 = euclidianDistance(data,c3)
        mn4 = euclidianDistance(data,c4)
        mn5 = euclidianDistance(data,c5)
        mn6 = euclidianDistance(data,c6)
        mn7 = euclidianDistance(data,c7)
        mn8 = euclidianDistance(data,c8)
        mn9 = euclidianDistance(data,c9)
        mn10 = euclidianDistance(data,c10)
       
        if mn1<mn2 and mn1<mn3 and mn1<mn4 and mn1<mn5 and mn1<mn6 and mn1<mn7 and mn1<mn8 and mn1<mn9 and mn1<mn10:
            g1.append(data)
        elif mn2<mn1 and mn2<mn3 and mn2<mn4 and mn2<mn5 and mn2<mn6 and mn2<mn7 and mn2<mn8 and mn2<mn9 and mn2<mn10:
            g2.append(data)
        elif mn3<mn1 and mn3<mn2 and mn3<mn4 and mn3<mn5 and mn3<mn6 and mn3<mn7 and mn3<mn8 and mn3<mn9 and mn3<mn10:
            g3.append(data)
        elif mn4<mn1 and mn4<mn2 and mn4<mn3 and mn4<mn5 and mn4<mn6 and mn4<mn7 and mn4<mn8 and mn4<mn9 and mn4<mn10:
            g4.append(data)
        elif mn5<mn1 and mn5<mn2 and mn5<mn3 and mn5<mn4 and mn5<mn6 and mn5<mn7 and mn5<mn8 and mn5<mn9 and mn5<mn10:
            g5.append(data)
        elif mn6<mn1 and mn6<mn2 and mn6<mn3 and mn6<mn4 and mn6<mn5 and mn6<mn7 and mn6<mn8 and mn6<mn9 and mn6<mn10:
            g6.append(data)
        elif mn7<mn1 and mn7<mn2 and mn7<mn3 and mn7<mn4 and mn7<mn6 and mn7<mn5 and mn7<mn8 and mn7<mn9 and mn7<mn10:
            g7.append(data)
        elif mn8<mn1 and mn8<mn2 and mn8<mn3 and mn8<mn4 and mn8<mn6 and mn8<mn5 and mn8<mn7 and mn8<mn9 and mn8<mn10:
            g8.append(data)
        elif mn9<mn1 and mn9<mn2 and mn9<mn3 and mn9<mn4 and mn9<mn6 and mn9<mn5 and mn9<mn7 and mn9<mn8 and mn9<mn10:
            g9.append(data)
        else:
            g10.append(data)
    return g1,g2,g3,g4,g5,g6,g7,g8,g9,g10

# %%
g1,g2,g3,g4,g5,g6,g7,g8,g9,g10= grouping(X)
c1 = average(g1)
c2 = average(g2)
c3 = average(g3)
c4 = average(g4)
c5 = average(g5)
c6 = average(g6)
c7 = average(g7)
c8 = average(g8)
c9 = average(g9)
c10 = average(g10)



while(1):
    g1,g2,g3,g4,g5,g6,g7,g8,g9,g10 = grouping(X)
    c1 = average(g1)
    c2 = average(g2)
    c3 = average(g3)
    c4 = average(g4)
    c5 = average(g5)
    c6 = average(g6)
    c7 = average(g7)
    c8 = average(g8)
    c9 = average(g9)
    c10 = average(g10)
    g1,g2,g3,g4,g5,g6,g7,g8,g9,g10 = grouping(X)
    c11 = average(g1)
    c22= average(g2)
    c33 = average(g3)
    c44 = average(g4)
    c55 = average(g5)
    c66 = average(g6)
    c77 = average(g7)
    c88 = average(g8)
    c99 = average(g9)
    c1010 = average(g10)
    if c1==c11 and c2==c22 and c3==c33 and c4==c44 and c5==c55 and c6==c66 and c7==c77 and c8==c88 and c9==c99 and c1010:
        break

# %%
plt.scatter(X[:,0],X[:,1],c=y )
colmap = {0: 'r', 1: 'r', 2: 'r', 3:'r',4: 'r', 5: 'b', 6: 'b', 7:'b',8:'b',9:'r'}
plt.scatter(c1[0], c1[1], color=colmap[0])
plt.scatter(c2[0], c2[1], color=colmap[1])
plt.scatter(c3[0], c3[1], color=colmap[2])
plt.scatter(c4[0], c4[1], color=colmap[3])
plt.scatter(c5[0], c5[1], color=colmap[4])
plt.scatter(c6[0], c6[1], color=colmap[5])
plt.scatter(c7[0], c7[1], color=colmap[6])
plt.scatter(c8[0], c8[1], color=colmap[7])
plt.scatter(c9[0], c9[1], color=colmap[8])
plt.scatter(c10[0], c10[1], color=colmap[9])
plt.show()

# %%
k = 12
c=get_random(k)
print(c)
c=list(c.values())
print(c)
c1=c[0]
c2=c[1]
c3=c[2]
c4=c[3]
c5=c[4]
c6=c[5]
c7=c[6]
c8=c[7]
c9=c[8]
c10=c[9]
c11=c[10]
c12=c[11]
# Out:
# [ 25 113 326 391 244   5 252 407 493   6 212 128]
# {0: array([0.8078951 , 0.78293359]), 1: array([1.79911052, 0.13884035]), 2: array([ 1.69177179, -0.34395554]), 3: array([ 0.37299044, -0.12632774]), 4: array([-0.63623143,  0.81583174]), 5: array([ 1.65281257, -0.10489339]), 6: array([0.00526482, 0.28918155]), 7: array([ 0.48322652, -0.2579707 ]), 8: array([-0.22942088,  1.08602227]), 9: array([0.16871966, 0.3573838 ]), 10: array([ 0.59006784, -0.2703807 ]), 11: array([0.79967316, 0.46405143])}
# [array([0.8078951 , 0.78293359]), array([1.79911052, 0.13884035]), array([ 1.69177179, -0.34395554]), array([ 0.37299044, -0.12632774]), array([-0.63623143,  0.81583174]), array([ 1.65281257, -0.10489339]), array([0.00526482, 0.28918155]), array([ 0.48322652, -0.2579707 ]), array([-0.22942088,  1.08602227]), array([0.16871966, 0.3573838 ]), array([ 0.59006784, -0.2703807 ]), array([0.79967316, 0.46405143])]

# %%
def grouping(X):
    g1 = []
    g2 = []
    g3 = []
    g4 = []
    g5 = []
    g6 = []
    g7 = []
    g8 = []
    g9 = []
    g10 = []
    g11 = []
    g12 = []
   
    
    sz = X.size
    sz/=2
    sz = int (sz)
    #print(sz)
    for i in range(sz):
        data = X[i]
        mn1 = euclidianDistance(data,c1)
        mn2 = euclidianDistance(data,c2)
        mn3 = euclidianDistance(data,c3)
        mn4 = euclidianDistance(data,c4)
        mn5 = euclidianDistance(data,c5)
        mn6 = euclidianDistance(data,c6)
        mn7 = euclidianDistance(data,c7)
        mn8 = euclidianDistance(data,c8)
        mn9 = euclidianDistance(data,c9)
        mn10 = euclidianDistance(data,c10)
        mn11 = euclidianDistance(data,c11)
        mn12 = euclidianDistance(data,c12)
       
        if mn1<mn2 and mn1<mn3 and mn1<mn4 and mn1<mn5 and mn1<mn6 and mn1<mn7 and mn1<mn8 and mn1<mn9 and mn1<mn10 and mn1<mn11 and mn1<mn12:
            g1.append(data)
        elif mn2<mn1 and mn2<mn3 and mn2<mn4 and mn2<mn5 and mn2<mn6 and mn2<mn7 and mn2<mn8 and mn2<mn9 and mn2<mn10 and mn2<mn11 and mn2<mn12:
            g2.append(data)
        elif mn3<mn1 and mn3<mn2 and mn3<mn4 and mn3<mn5 and mn3<mn6 and mn3<mn7 and mn3<mn8 and mn3<mn9 and mn3<mn10 and mn3<mn11 and mn3<mn12:
            g3.append(data)
        elif mn4<mn1 and mn4<mn2 and mn4<mn3 and mn4<mn5 and mn4<mn6 and mn4<mn7 and mn4<mn8 and mn4<mn9 and mn4<mn10 and mn4<mn11 and mn4<mn12:
            g4.append(data)
        elif mn5<mn1 and mn5<mn2 and mn5<mn3 and mn5<mn4 and mn5<mn6 and mn5<mn7 and mn5<mn8 and mn5<mn9 and mn5<mn10 and mn5<mn11 and mn5<mn12:
            g5.append(data)
        elif mn6<mn1 and mn6<mn2 and mn6<mn3 and mn6<mn4 and mn6<mn5 and mn6<mn7 and mn6<mn8 and mn6<mn9 and mn6<mn10 and mn6<mn11 and mn6<mn12:
            g6.append(data)
        elif mn7<mn1 and mn7<mn2 and mn7<mn3 and mn7<mn4 and mn7<mn6 and mn7<mn5 and mn7<mn8 and mn7<mn9 and mn7<mn10 and mn7<mn11 and mn7<mn12:
            g7.append(data)
        elif mn8<mn1 and mn8<mn2 and mn8<mn3 and mn8<mn4 and mn8<mn6 and mn8<mn5 and mn8<mn7 and mn8<mn9 and mn8<mn10 and mn8<mn11 and mn8<mn12:
            g8.append(data)
        elif mn9<mn1 and mn9<mn2 and mn9<mn3 and mn9<mn4 and mn9<mn6 and mn9<mn5 and mn9<mn7 and mn9<mn8 and mn9<mn10 and mn9<mn11 and mn9<mn12:
            g9.append(data)
        elif mn10<mn1 and mn10<mn2 and mn10<mn3 and mn10<mn4 and mn10<mn6 and mn10<mn5 and mn10<mn7 and mn10<mn9 and mn10<mn8 and mn10<mn11 and mn10<mn12:
            g10.append(data)
        elif mn11<mn1 and mn11<mn2 and mn11<mn3 and mn11<mn4 and mn11<mn6 and mn11<mn5 and mn11<mn7 and mn11<mn8 and mn11<mn10 and mn11<mn9 and mn11<mn12:
            g11.append(data)   
        else:
            g12.append(data)
    return g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,g12

# %%
g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,g12= grouping(X)
c1 = average(g1)
c2 = average(g2)
c3 = average(g3)
c4 = average(g4)
c5 = average(g5)
c6 = average(g6)
c7 = average(g7)
c8 = average(g8)
c9 = average(g9)
c10 = average(g10)
c11 = average(g11)
c12 = average(g12)


count=0
while(1):
    g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,g12 = grouping(X)
    c1 = average(g1)
    c2 = average(g2)
    c3 = average(g3)
    c4 = average(g4)
    c5 = average(g5)
    c6 = average(g6)
    c7 = average(g7)
    c8 = average(g8)
    c9 = average(g9)
    c10 = average(g10)
    c11 = average(g11)
    c12 = average(g12)
    g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,g12 = grouping(X)
    c11 = average(g1)
    c22= average(g2)
    c33 = average(g3)
    c44 = average(g4)
    c55 = average(g5)
    c66 = average(g6)
    c77 = average(g7)
    c88 = average(g8)
    c99 = average(g9)
    c1010 = average(g10)
    cT= average(g11)
    cV = average(g12)
    count+=1
    
    break
    if c1==c11 and c2==c22 and c3==c33 and c4==c44 and c5==c55 and c6==c66 and c7==c77 and c8==c88 and c9==c99 and c10==c1010 and c11==cT and c12==cV:
        break

# %%
plt.scatter(X[:,0],X[:,1],c=y )
colmap = {0: 'r', 1: 'r', 2: 'r', 3:'r',4: 'r', 5: 'b', 6: 'b', 7:'b',8:'b',9:'r',10:'b',11:'r'}
plt.scatter(c1[0], c1[1], color=colmap[0])
plt.scatter(c2[0], c2[1], color=colmap[1])
plt.scatter(c3[0], c3[1], color=colmap[2])
plt.scatter(c4[0], c4[1], color=colmap[3])
plt.scatter(c5[0], c5[1], color=colmap[4])
plt.scatter(c6[0], c6[1], color=colmap[5])
plt.scatter(c7[0], c7[1], color=colmap[6])
plt.scatter(c8[0], c8[1], color=colmap[7])
plt.scatter(c9[0], c9[1], color=colmap[8])
plt.scatter(c10[0], c10[1], color=colmap[9])
plt.scatter(c11[0], c11[1], color=colmap[10])
plt.scatter(c12[0], c12[1], color=colmap[11])
plt.show()

# %% [markdown]
# ### Honor Code
# Plese type the following in the next cell. Replace the underlined text with your own.
#
# I am <u>Kutub uddin</u> bearing registration no. <u>170103020047</u> hereby declaring that I myself did my assignments, I didn't directly copy any code from others. I have a complete understanding of my code and can explain. I respect this honor code and I believe it will be useful to maintain academic integrity.<br>
#
# Name: <u>Kutub uddin</u><br>
# Date: <u>25/7/2020</u>

# %% [markdown]
# _your__writing_
